# %% [markdown]
# <a href="https://colab.research.google.com/github/ChristianCasino/AIDA_LAB-CPE/blob/main/Casino_201911462_MIDTERMS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import pearsonr
import math

# %% [markdown]
# 1.)

# %%
x = [10,15,20,25,30,35]
y =[68,60,55,48,38,32]

def calculateB(x, y, n):
   
    sx = sum(x)
    sy = sum(y)
    sxsy = 0
    sx2 = 0
 
    for i in range(n):
        sxsy += x[i] * y[i]
        sx2 += x[i] * x[i]
    b = (n * sxsy - sx * sy)/(n * sx2 - sx * sx)
    return b
 

def leastRegLine(X,Y,n):
     
    b = calculateB(X, Y, n)
    meanX = int(sum(X)/n)
    meanY = int(sum(Y)/n)
 
    
    a = meanY - b * meanX
    print("Regression line:")
    print("Y = ", '%.3f'%a, " + ", '%.3f'%b, "*X", sep="")
    

X1 = [10,15,20,25,30,35]
Y1 =[68,60,55,48,38,32]
n = len(X1)
leastRegLine(X1, Y1, n)
# Out:
# Regression line:
# Y = 81.806 + -1.446*X

# %% [markdown]
# ### 2.)

# %% [markdown]
# a.)

# %%
def MCC(sumx, sumy, sumxx, sumyy, sumxy,n):
  r = ((n*sumxy) - (sumx*sumy))/math.sqrt(((n*sumxx)-(sumxx))*((n*sumyy)-(sumyy)))
  return print("The value of the product moment correlation coefficient for these data is ", r)
MCC(52,225,380,7007,1335,8)
# Out:
# The value of the product moment correlation coefficient for these data is  -0.08929852279172255

# %% [markdown]
# ### 3.)

# %% [markdown]
# a.)

# %%
MCC(200,436,7250,39234,12515,6)
# Out:
# The value of the product moment correlation coefficient for these data is  -0.143606415352966

# %% [markdown]
# # 4.)

# %% [markdown]
# a.

# %%
def estimate_coef(x, y):

    n = np.size(x)
    m_x = np.mean(x)
    m_y = np.mean(y)
    SS_xy = np.sum(y*x) - n*m_y*m_x
    SS_xx = np.sum(x*x) - n*m_x*m_x
    b_1 = SS_xy / SS_xx
    b_0 = m_y - b_1*m_x
    return (b_0, b_1)
  
def plot_regression_line(x, y, b):
    
    plt.scatter(x, y, color = "m",
               marker = "o", s = 30)
    y_pred = b[0] + b[1]*x
    plt.plot(x, y_pred, color = "g")
    plt.xlabel('x')
    plt.ylabel('y')
    plt.show()
  
def main():
    x = np.array([0,10,20,30,40,50,60])
    y = np.array([16,27,28,39,39,48,51])
    b = estimate_coef(x, y)
    plot_regression_line(x, y, b)
  
if __name__ == "__main__":
    main()

# %% [markdown]
# b.)

# %%
x = [0,10,20,30,40,50,60]
y = [16,27,28,39,39,48,51]
n = len(x)
leastRegLine(x, y, n)
# Out:
# Regression line:
# Y = 18.071 + 0.564*X

# %% [markdown]
# ## 5.)

# %% [markdown]
# a.)

# %%
def main():
    x = np.array([1,1.5,2,2.5,3,3.5,4,4.5])
    y = np.array([3.9,4.4,5.8,6.6,7,7.1,7.3,7.7])
    b = estimate_coef(x, y)
    plot_regression_line(x, y, b)
  
if __name__ == "__main__":
    main()

# %% [markdown]
# b.)

# %%
x5 = [1,1.5,2,2.5,3,3.5,4,4.5]
y5 = [3.9,4.4,5.8,6.6,7,7.1,7.3,7.7]
n = len(x5)
leastRegLine(x5, y5, n)
# Out:
# Regression line:
# Y = 3.838 + 1.081*X

# %% [markdown]
# ### 6.)

# %% [markdown]
# a.)

# %%
def main():
    x = np.array([100,200,300,400,500,600] )
    y = np.array([228,236,256,278,285,301])
    b = estimate_coef(x, y)
    plot_regression_line(x, y, b)
  
if __name__ == "__main__":
    main()

# %% [markdown]
# b.)

# %%
x6=[100,200,300,400,500,600] 
y6=[228,236,256,278,285,301]
n = len(x6)
leastRegLine(x6, y6, n)
# Out:
# Regression line:
# Y = 210.600 + 0.153*X

# %% [markdown]
# ### 7.)

# %% [markdown]
# a.)

# %%
def main():
    x = np.array([40,10,100,110,120,150,20,90,80,130] )
    y = np.array([56,62,195,330,94,270,48,196,214,286])
    b = estimate_coef(x, y)
    plot_regression_line(x, y, b)
  
if __name__ == "__main__":
    main()

# %% [markdown]
# b.)

# %%
x7= [40,10,100,110,120,150,20,90,80,130]
y7=[56,62,195,330,94,270,48,196,214,286]
n = len(x7)
leastRegLine(x7, y7, n)
# Out:
# Regression line:
# Y = 30.164 + 1.704*X

# %% [markdown]
# ### 8.)

# %% [markdown]
# a.

# %%
def main():
    x = np.array([4.3,6.9,0,10.4,5.2,1.8,8,9.2,2.1] )
    y = np.array([224,208,123,419,230,184,362,351,196])
    b = estimate_coef(x, y)
    plot_regression_line(x, y, b)

if __name__ == "__main__":
    main()

# %% [markdown]
# b.)

# %%
x8= [4.3,6.9,0,10.4,5.2,1.8,8,9.2,2.1]
y8= [224,208,123,419,230,184,362,351,196]
n = len(x8)
leastRegLine(x8, y8, n)
# Out:
# Regression line:
# Y = 128.613 + 25.277*X
